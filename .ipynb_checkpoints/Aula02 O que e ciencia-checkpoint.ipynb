# %% [markdown]
# # Informações da Disciplina
#
# ## MC211 - Metodologia Científica
#
# ## Dept Engenharia Elétrica
#
# ## Faculdade de Engenharia e Ciências de Guaratinguetá
#
# ## Universidade Estadual Paulista
#
#
# ---
# # Versão 2025
#
# ## Essas notas de aula podem ser compartilhadas nos termos da licença Creative Commons CC BY-NC-ND 4.0, com propósitos exclusivamente educacionais.
#
# ## Attribution-NonCommercial-NoDerivatives 4.0 International
# ![](imagens/CC.png)
#
#
# ---
# # Causal Inference Rosenbaum, Paul R.
#
# ![right:50% w:500](imagens/Foto01.jpg)
#
# ---
# # Causal Inference Rosenbaum, Paul R.
#
# ![right:50% w:500](imagens/Foto03.jpg).image.png
#
# ---
# # https://www.merriam-webster.com/dictionary/black%20bile
#
# 1. **bile negra**:
# acreditava-se que era fria e seca e causava melancolia e covardia
#
# 2. **catarro**
# 1: muco viscoso secretado em quantidade anormal nas vias respiratórias
# 2: acreditava-se que era fria e úmida e, causava letargia
#
# 3. **sangue**
# acreditava-se que era quente e úmida e causava alegria e otimismo
#
# 4. **bile amarela**:
# acreditava-se que era quente e seca e causava raiva e irritabilidade
#
# ---
#
# ![](imagens/Foto02.jpg).
#
# ---
# # __ciências empíricas__
#
# ## As __ciências empíricas__ (também chamadas de experimentais, reais ou factuais) se encarregam de estudar a natureza auxiliando-se na observação e na experimentação.
#
# ## Essas ciências estudam feitos que ocorrem no mundo perceptível e, consequentemente, precisam usar o exame de evidência empírica para comprová-las.
#
# ---
# # Ciências Empíricas
# ### (https://knoow.net/cienciasexactas/fisica/ciencias-empiricas/)
#
# ## As Ciências Empíricas são todas as ciências que estudam fatos e cujas teorias podem ser confirmadas ou refutadas por dados observacionais ou através da experimentação.
#
# ## **De acordo com esta definição, apenas a matemática e a lógica não são ciências empíricas, sendo consideradas como ciências formais**.
#
# ---
# ## Nas ciências empíricas o ponto de partida são os princípios, isto é, deduções formuladas como interpretações, generalizações e abstrações de um saber anterior. P.Exemplo
#
# ## Geometria Euclideana e geometria Lobachevskiana
#
# ### significa que o quinto postulado de Euclides, o clássico postulado das paralelas da geometria euclidiana é substituído pelo postulado de Lobachesvky:
#
#     "Por um ponto fora de uma reta dada passa mais de uma paralela a essa reta."
#
# ### O postulado das paralelas, na geometria euclidiana, é equivalente à afirmação de que, no espaço bidimensional, para qualquer reta R e ponto P não contido em R, existe somente uma reta que passa por P e não intercepta R, ou seja, uma linha que é paralela a R. Na geometria hiperbólica, existem infinitas retas distintas que passam por P e que não interceptam R, de modo que o postulado clássico das paralelas é falso.
#
# https://pt.wikipedia.org/wiki/Geometria_hiperb%C3%B3lica
#
# ---
#
# ## **São estes princípios que servem de base para a formulação das hipóteses, e é a partir deles que se podem deduzir as consequências.**
#
# ## A partir daí o cientista busca determinadas regularidades, identifica propriedades a serem generalizadas, estabelece leis que determinem a evolução do sistema considerado e que sirvam de princípio geral.
#
# ---
#
# ## Na posse de tais princípios, o cientista está então em condições de, por via da observação e da experimentação, identificar e comprovar características gerais e exatas.
#
# ## Quando esta formulação conseguir êxito, inicia-se então o desenvolvimento das consequências, que revelam muitas vezes relações insuspeitadas, que ultrapassam o campo dos fatos a partir dos quais foram identificados os princípios.
#
# ---
# ## As ciências empíricas podem ser divididas em dois grandes grupos: as ciências naturais e as ciências sociais
#
# ### **no caso das ciências naturais, o alvo é o estudo na natureza na totalidade e inclui a física, a química, a biologia, entre diversas outras**
#
# ### **quanto às ciências sociais, são estudados os aspectos sociais e humanos e inclui a história, a sociologia, a psicologia, a antropologia, a economia, o direito e a política.**
#
# ---
#
# ## As regras metodológicas nos fornecem critérios para a avaliação dos procedimentos científicos. Uma regra não é verdadeira ou falsa. As regras são convenções do jogo da ciência. Não adotamos regras isoladamente mas um conjuntos de regras.
#
# ---
# # Texto: A Lógica da Pesquisa Científica Karl Popper
#
# ## Regra Metodológica Apresentada como Convenção (Pg 55)
#
# ---
#
# ## Dois exemplos simples de regras metodológicas:
# ## **1. O jogo da ciência é, em princípio, interminável. Quem decida, um dia, que os enunciados científicos não mais exigem prova, e podem ser vistos como definitivamente verificados, retira-se do jogo;**
# ## **2. Uma vez proposta e submetida a prova a hipótese e tendo ela comprovado suas qualidade, não se pode permitir seu afastamento sem uma "boa razão". Uma "boa razão" será, por exemplo, sua substituição por outra hipótese, que resista melhor às provas, ou que o falseamento de uma consequência da primeira hipótese.**
#
# ---
# # "Uma teoria científica é um modelo ("matemático") que descreve e codifica as observações que fazemos. Assim, uma boa teoria deverá descrever uma vasta série de fenômenos com base em alguns postulados simples como também deverá ser capaz de fazer previsões claras as quais poderão ser testadas."
#
# https://educacao.uol.com.br/disciplinas/filosofia/filosofia-da-ciencia-karl-popper-falseabilidade-e-limites-da-ciencia.htm
#
# ---
# ## Popper defendeu que, se a ciência se baseia na observação e teorização, só se podem tirar conclusões sobre o que foi observado, nunca sobre o que não foi.
#
# ### Assim, se um cientista observa milhares de cisnes, em muitos lugares diferentes e verifica que todos os cisnes observados são brancos, isto não lhe permite afirmar cientificamente que todos os cisnes são brancos, pois, não importa quantos cisnes brancos tenham sido observados, basta o surgimento de um único cisne negro para derrubar a afirmação de que eles não existiriam.
#
# ---
# ## **Qualquer afirmação científica baseada em observação jamais poderá ser considerada uma verdade absoluta ou definitiva.**
#
# ## **Uma teoria científica, no máximo, pode ser considerada válida até quando provada falsa por outras observações, testes e teorias, mais abrangentes ou exatos que a original.**
#
# ---
# # Falseabilidade
#
# ## A possibilidade de uma teoria ser refutada constituía a própria essência da natureza científica. Assim, uma teoria só pode ser considerada científica quando é falseável, ou seja, quando é possível prová-la falsa. Esse conceito ficou conhecido como falseabilidade ou refutabilidade.
#
# ---
# ## **Segundo Popper, o que não é falseável ou refutável não pode ser considerado científico. As teorias da gravitação universal de Isaac Newton são científicas, porque além de se enquadrarem na definição ao propor modelos ("equações") simples que descrevem os modelos cósmicos gravitacionais, também é possível se fazer previsões acertadas com base nelas.**
#
# ---
# ## E as teorias de Newton também são falseáveis. Tanto que o foram, quando Albert Einstein com sua Teoria da Relatividade demonstrou que a mecânica newtoniana era inválida em velocidades próximas à da luz.
#
# ---
# # Os Limites da ciência
#
# ![bg left:35% w:500](imagens/Karl_Popper.jpg)
#
# ## Com Popper, os limites da ciência se definem claramente. A ciência produz teorias falseáveis, que serão válidas enquanto não refutadas. Por este modelo, não há como a ciência tratar de assuntos do domínio da religião, que tem suas doutrinas como verdades eternas, ou da filosofia, que busca verdades absolutas.
#
#
# ---
# ## O melhor no velho filósofo, que se opôs ao nazismo e dedicou sua vida à defesa de boas causas, é que suas teorias se aplicam a elas próprias. Assim, se amanhã alguém redigir uma melhor definição de teoria científica, as ideias de Popper sairão humildemente de cena para tomar seu lugar na história da ciência.
#
# ## Entre as muitas virtudes que nossa ciência adquiriu dos grandes sábios que lhe deram grandeza, Popper nos mostrou uma ciência que se faz grande na virtude da humildade.

# %%
from IPython.display import Video

Video("imagens/Verdade.mp4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from IPython.display import Video
# ----> 3 Video("imagens/Verdade.mp4")
#
# File ~/my-jupyter-env/lib/python3.12/site-packages/IPython/core/display.py:1242, in Video.__init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1236 if data and not embed:
#    1237     msg = ''.join([
#    1238         "To embed videos, you must pass embed=True ",
#    1239         "(this may make your notebook files huge)\n",
#    1240         "Consider passing Video(url='...')",
#    1241     ])
# -> 1242     raise ValueError(msg)
#    1244 self.mimetype = mimetype
#    1245 self.embed = embed
#
# ValueError: To embed videos, you must pass embed=True (this may make your notebook files huge)
# Consider passing Video(url='...')
